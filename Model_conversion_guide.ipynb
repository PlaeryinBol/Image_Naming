# %% [markdown]
# ## Model Conversion Guide

# %% [markdown]
# In this notebook, we will consider the full path (*torch* → *onnx* → *tf-protobuf* → *tf-saved_model* → *tf-serving*) of converting models for output to production using the wsl-encoder as an example.

# %%
import torch
import torch.nn as nn
import torch.nn.init as init
import torch.utils.model_zoo as model_zoo
import numpy as np
from PIL import Image
import torchvision as tv

model_wsl = torch.hub.load('facebookresearch/WSL-Images', 'resnext101_32x8d_wsl')

# %% [markdown]
# ### Torch

# %%
# Encoder model that receives features from the input image
class Wsl_encoder(nn.Module):
    def __init__(self):
        super(Wsl_encoder, self).__init__()
        self.net = model_wsl
        self.net = nn.Sequential(*list(self.net.children())[:-2])

    def forward(self, x):
        x = self.net(x)
        x = x.permute(0, 2, 3, 1)
        x = x.view(x.size(0), -1, x.size(-1))
        return x

torch_encoder = Wsl_encoder()
torch_encoder.eval();

# %%
# Input image preprocessing
data_transforms = tv.transforms.Compose([
    tv.transforms.Resize((299, 299)),
    tv.transforms.ToTensor(),
    tv.transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

def preprocessing_image(img_path):
    with open(img_path, 'rb') as f:
        img = Image.open(f)
        img = img.convert('RGB')
        img = data_transforms(img)
        img = torch.FloatTensor(img)
        img = img.unsqueeze(0)
    return img

# %%
# We will get features for two pictures in order to later understand that the model produces different results for different inputs
img_path = r'E:\0.jpg'
img_path_1 = r'E:\1.jpg'
image = preprocessing_image(img_path)
image_1 = preprocessing_image(img_path_1)

torch_features = torch_encoder(image)
torch_features_1 = torch_encoder(image_1)

# Let's look at the output tensor itself
torch_features  # torch.Size([1, 100, 2048])
# Out:
# tensor([[[0.0000, 0.2136, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0406, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 2.0856,  ..., 0.0000, 0.3631, 0.0000],
#          [0.0000, 0.0000, 1.6003,  ..., 0.0000, 0.9627, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]],
#        grad_fn=<ViewBackward>)

# %% [markdown]
# ### Onnx

# %%
import torch.onnx
import onnx
import onnxruntime

# %%
# Let's convert the model to onnx
torch.onnx.export(torch_encoder,
                  args=image,
                  f='wsl_encoder.onnx',
                  verbose=True,
                  export_params=True,
                  do_constant_folding=True,
                  opset_version=10,
                  input_names=['input_image'],
                  output_names=['output_features'],
                  # specify that the batch_size parameter can change
                  dynamic_axes={'input_image' : {0 : 'batch_size'},
                                'output_features' : {0 : 'batch_size'}})
# Out:
# graph(%input_image : Float(1, 3, 299, 299),
#       %net.0.weight : Float(64, 3, 7, 7),
#       %net.1.weight : Float(64),
#       %net.1.bias : Float(64),
#       %net.1.running_mean : Float(64),
#       %net.1.running_var : Float(64),
#       %net.4.0.conv1.weight : Float(256, 64, 1, 1),
#       %net.4.0.bn1.weight : Float(256),
#       %net.4.0.bn1.bias : Float(256),
#       %net.4.0.bn1.running_mean : Float(256),
#       %net.4.0.bn1.running_var : Float(256),
#       %net.4.0.conv2.weight : Float(256, 8, 3, 3),
#       %net.4.0.bn2.weight : Float(256),
#       %net.4.0.bn2.bias : Float(256),
#       %net.4.0.bn2.running_mean : Float(256),
#       %net.4.0.bn2.running_var : Float(256),
#       %net.4.0.conv3.weight : Float(256, 256, 1, 1),
#       %net.4.0.bn3.weight : Float(256),
#       %net.4.0.bn3.bias : Float(256),
#       %net.4.0.bn3.running_mean : Float(256),
#       %net.4.0.bn3.running_var : Float(256),
#       %net.4.0.downsample.0.weight : Float(256, 64, 1, 1),
#       %net.4.0.downsample.1.weight : Float(256),
#       %net.4.0.downsample.1.bias : Float(256),
#       %net.4.0.downsample.1.running_mean : Float(256),
#       %net.4.0.downsample.1.running_var : Float(256),
#       %net.4.1.conv1.weight : Float(256, 256, 1, 1),
#       %net.4.1.bn1.weight : Float(256),
#       %net.4.1.bn1.bias : Float(256),
#       %net.4.1.bn1.running_mean : Float(256),
#       %net.4.1.bn1.running_var : Float(256),
#       %net.4.1.conv2.weight : Float(256, 8, 3, 3),
#       %net.4.1.bn2.weight : Float(256),
#       %net.4.1.bn2.bias : Float(256),
#       %net.4.1.bn2.running_mean : Float(256),
#       %net.4.1.bn2.running_var : Float(256),
#       %net.4.1.conv3.weight : Float(256, 256, 1, 1),
#       %net.4.1.bn3.weight : Float(256),
#       %net.4.1.bn3.bias : Float(256),
#       %net.4.1.bn3.running_mean : Float(256),
#       %net.4.1.bn3.running_var : Float(256),
#       %net.4.2.conv1.weight : Float(256, 256, 1, 1),
#       %net.4.2.bn1.weight : Float(256),
#       %net.4.2.bn1.bias : Float(256),
#       %net.4.2.bn1.running_mean : Float(256),
#       %net.4.2.bn1.running_var : Float(256),
#       %net.4.2.conv2.weight : Float(256, 8, 3, 3),
#       %net.4.2.bn2.weight : Float(256),
#       %net.4.2.bn2.bias : Float(256),
#       %net.4.2.bn2.running_mean : Float(256),
#       %net.4.2.bn2.running_var : Float(256),
#       %net.4.2.conv3.weight : Float(256, 256, 1, 1),
#       %net.4.2.bn3.weight : Float(256),
#       %net.4.2.bn3.bias : Float(256),
#       %net.4.2.bn3.running_mean : Float(256),
#       %net.4.2.bn3.running_var : Float(256),
#       %net.5.0.conv1.weight : Float(512, 256, 1, 1),
#       %net.5.0.bn1.weight : Float(512),
#       %net.5.0.bn1.bias : Float(512),
#       %net.5.0.bn1.running_mean : Float(512),
#       %net.5.0.bn1.running_var : Float(512),
#       %net.5.0.conv2.weight : Float(512, 16, 3, 3),
#       %net.5.0.bn2.weight : Float(512),
#       %net.5.0.bn2.bias : Float(512),
#       %net.5.0.bn2.running_mean : Float(512),
#       %net.5.0.bn2.running_var : Float(512),
#       %net.5.0.conv3.weight : Float(512, 512, 1, 1),
#       %net.5.0.bn3.weight : Float(512),
#       %net.5.0.bn3.bias : Float(512),
#       %net.5.0.bn3.running_mean : Float(512),
#       %net.5.0.bn3.running_var : Float(512),
#       %net.5.0.downsample.0.weight : Float(512, 256, 1, 1),
#       %net.5.0.downsample.1.weight : Float(512),
#       %net.5.0.downsample.1.bias : Float(512),
#       %net.5.0.downsample.1.running_mean : Float(512),
#       %net.5.0.downsample.1.running_var : Float(512),
#       %net.5.1.conv1.weight : Float(512, 512, 1, 1),
#       %net.5.1.bn1.weight : Float(512),
#       %net.5.1.bn1.bias : Float(512),
#       %net.5.1.bn1.running_mean : Float(512),
#       %net.5.1.bn1.running_var : Float(512),
#       %net.5.1.conv2.weight : Float(512, 16, 3, 3),
#       %net.5.1.bn2.weight : Float(512),
#       %net.5.1.bn2.bias : Float(512),
#       %net.5.1.bn2.running_mean : Float(512),
#       %net.5.1.bn2.running_var : Float(512),
#       %net.5.1.conv3.weight : Float(512, 512, 1, 1),
#       %net.5.1.bn3.weight : Float(512),
#       %net.5.1.bn3.bias : Float(512),
#       %net.5.1.bn3.running_mean : Float(512),
#       %net.5.1.bn3.running_var : Float(512),
#       %net.5.2.conv1.weight : Float(512, 512, 1, 1),
#       %net.5.2.bn1.weight : Float(512),
#       %net.5.2.bn1.bias : Float(512),
#       %net.5.2.bn1.running_mean : Float(512),
#       %net.5.2.bn1.running_var : Float(512),
#       %net.5.2.conv2.weight : Float(512, 16, 3, 3),
#       %net.5.2.bn2.weight : Float(512),
#       %net.5.2.bn2.bias : Float(512),
#       %net.5.2.bn2.running_mean : Float(512),
#       %net.5.2.bn2.running_var : Float(512),
#       %net.5.2.conv3.weight : Float(512, 512, 1, 1),
#       %net.5.2.bn3.weight : Float(512),
#       %net.5.2.bn3.bias : Float(512),
#       %net.5.2.bn3.running_mean : Float(512),
#       %net.5.2.bn3.running_var : Float(512),
#       %net.5.3.conv1.weight : Float(512, 512, 1, 1),
#       %net.5.3.bn1.weight : Float(512),
#       %net.5.3.bn1.bias : Float(512),
#       %net.5.3.bn1.running_mean : Float(512),
#       %net.5.3.bn1.running_var : Float(512),
#       %net.5.3.conv2.weight : Float(512, 16, 3, 3),
#       %net.5.3.bn2.weight : Float(512),
#       %net.5.3.bn2.bias : Float(512),
#       %net.5.3.bn2.running_mean : Float(512),
#       %net.5.3.bn2.running_var : Float(512),
#       %net.5.3.conv3.weight : Float(512, 512, 1, 1),
#       %net.5.3.bn3.weight : Float(512),
#       %net.5.3.bn3.bias : Float(512),
#       %net.5.3.bn3.running_mean : Float(512),
#       %net.5.3.bn3.running_var : Float(512),
#       %net.6.0.conv1.weight : Float(1024, 512, 1, 1),
#       %net.6.0.bn1.weight : Float(1024),
#       %net.6.0.bn1.bias : Float(1024),
#       %net.6.0.bn1.running_mean : Float(1024),
#       %net.6.0.bn1.running_var : Float(1024),
#       %net.6.0.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.0.bn2.weight : Float(1024),
#       %net.6.0.bn2.bias : Float(1024),
#       %net.6.0.bn2.running_mean : Float(1024),
#       %net.6.0.bn2.running_var : Float(1024),
#       %net.6.0.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.0.bn3.weight : Float(1024),
#       %net.6.0.bn3.bias : Float(1024),
#       %net.6.0.bn3.running_mean : Float(1024),
#       %net.6.0.bn3.running_var : Float(1024),
#       %net.6.0.downsample.0.weight : Float(1024, 512, 1, 1),
#       %net.6.0.downsample.1.weight : Float(1024),
#       %net.6.0.downsample.1.bias : Float(1024),
#       %net.6.0.downsample.1.running_mean : Float(1024),
#       %net.6.0.downsample.1.running_var : Float(1024),
#       %net.6.1.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.1.bn1.weight : Float(1024),
#       %net.6.1.bn1.bias : Float(1024),
#       %net.6.1.bn1.running_mean : Float(1024),
#       %net.6.1.bn1.running_var : Float(1024),
#       %net.6.1.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.1.bn2.weight : Float(1024),
#       %net.6.1.bn2.bias : Float(1024),
#       %net.6.1.bn2.running_mean : Float(1024),
#       %net.6.1.bn2.running_var : Float(1024),
#       %net.6.1.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.1.bn3.weight : Float(1024),
#       %net.6.1.bn3.bias : Float(1024),
#       %net.6.1.bn3.running_mean : Float(1024),
#       %net.6.1.bn3.running_var : Float(1024),
#       %net.6.2.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.2.bn1.weight : Float(1024),
#       %net.6.2.bn1.bias : Float(1024),
#       %net.6.2.bn1.running_mean : Float(1024),
#       %net.6.2.bn1.running_var : Float(1024),
#       %net.6.2.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.2.bn2.weight : Float(1024),
#       %net.6.2.bn2.bias : Float(1024),
#       %net.6.2.bn2.running_mean : Float(1024),
#       %net.6.2.bn2.running_var : Float(1024),
#       %net.6.2.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.2.bn3.weight : Float(1024),
#       %net.6.2.bn3.bias : Float(1024),
#       %net.6.2.bn3.running_mean : Float(1024),
#       %net.6.2.bn3.running_var : Float(1024),
#       %net.6.3.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.3.bn1.weight : Float(1024),
#       %net.6.3.bn1.bias : Float(1024),
#       %net.6.3.bn1.running_mean : Float(1024),
#       %net.6.3.bn1.running_var : Float(1024),
#       %net.6.3.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.3.bn2.weight : Float(1024),
#       %net.6.3.bn2.bias : Float(1024),
#       %net.6.3.bn2.running_mean : Float(1024),
#       %net.6.3.bn2.running_var : Float(1024),
#       %net.6.3.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.3.bn3.weight : Float(1024),
#       %net.6.3.bn3.bias : Float(1024),
#       %net.6.3.bn3.running_mean : Float(1024),
#       %net.6.3.bn3.running_var : Float(1024),
#       %net.6.4.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.4.bn1.weight : Float(1024),
#       %net.6.4.bn1.bias : Float(1024),
#       %net.6.4.bn1.running_mean : Float(1024),
#       %net.6.4.bn1.running_var : Float(1024),
#       %net.6.4.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.4.bn2.weight : Float(1024),
#       %net.6.4.bn2.bias : Float(1024),
#       %net.6.4.bn2.running_mean : Float(1024),
#       %net.6.4.bn2.running_var : Float(1024),
#       %net.6.4.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.4.bn3.weight : Float(1024),
#       %net.6.4.bn3.bias : Float(1024),
#       %net.6.4.bn3.running_mean : Float(1024),
#       %net.6.4.bn3.running_var : Float(1024),
#       %net.6.5.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.5.bn1.weight : Float(1024),
#       %net.6.5.bn1.bias : Float(1024),
#       %net.6.5.bn1.running_mean : Float(1024),
#       %net.6.5.bn1.running_var : Float(1024),
#       %net.6.5.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.5.bn2.weight : Float(1024),
#       %net.6.5.bn2.bias : Float(1024),
#       %net.6.5.bn2.running_mean : Float(1024),
#       %net.6.5.bn2.running_var : Float(1024),
#       %net.6.5.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.5.bn3.weight : Float(1024),
#       %net.6.5.bn3.bias : Float(1024),
#       %net.6.5.bn3.running_mean : Float(1024),
#       %net.6.5.bn3.running_var : Float(1024),
#       %net.6.6.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.6.bn1.weight : Float(1024),
#       %net.6.6.bn1.bias : Float(1024),
#       %net.6.6.bn1.running_mean : Float(1024),
#       %net.6.6.bn1.running_var : Float(1024),
#       %net.6.6.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.6.bn2.weight : Float(1024),
#       %net.6.6.bn2.bias : Float(1024),
#       %net.6.6.bn2.running_mean : Float(1024),
#       %net.6.6.bn2.running_var : Float(1024),
#       %net.6.6.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.6.bn3.weight : Float(1024),
#       %net.6.6.bn3.bias : Float(1024),
#       %net.6.6.bn3.running_mean : Float(1024),
#       %net.6.6.bn3.running_var : Float(1024),
#       %net.6.7.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.7.bn1.weight : Float(1024),
#       %net.6.7.bn1.bias : Float(1024),
#       %net.6.7.bn1.running_mean : Float(1024),
#       %net.6.7.bn1.running_var : Float(1024),
#       %net.6.7.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.7.bn2.weight : Float(1024),
#       %net.6.7.bn2.bias : Float(1024),
#       %net.6.7.bn2.running_mean : Float(1024),
#       %net.6.7.bn2.running_var : Float(1024),
#       %net.6.7.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.7.bn3.weight : Float(1024),
#       %net.6.7.bn3.bias : Float(1024),
#       %net.6.7.bn3.running_mean : Float(1024),
#       %net.6.7.bn3.running_var : Float(1024),
#       %net.6.8.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.8.bn1.weight : Float(1024),
#       %net.6.8.bn1.bias : Float(1024),
#       %net.6.8.bn1.running_mean : Float(1024),
#       %net.6.8.bn1.running_var : Float(1024),
#       %net.6.8.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.8.bn2.weight : Float(1024),
#       %net.6.8.bn2.bias : Float(1024),
#       %net.6.8.bn2.running_mean : Float(1024),
#       %net.6.8.bn2.running_var : Float(1024),
#       %net.6.8.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.8.bn3.weight : Float(1024),
#       %net.6.8.bn3.bias : Float(1024),
#       %net.6.8.bn3.running_mean : Float(1024),
#       %net.6.8.bn3.running_var : Float(1024),
#       %net.6.9.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.9.bn1.weight : Float(1024),
#       %net.6.9.bn1.bias : Float(1024),
#       %net.6.9.bn1.running_mean : Float(1024),
#       %net.6.9.bn1.running_var : Float(1024),
#       %net.6.9.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.9.bn2.weight : Float(1024),
#       %net.6.9.bn2.bias : Float(1024),
#       %net.6.9.bn2.running_mean : Float(1024),
#       %net.6.9.bn2.running_var : Float(1024),
#       %net.6.9.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.9.bn3.weight : Float(1024),
#       %net.6.9.bn3.bias : Float(1024),
#       %net.6.9.bn3.running_mean : Float(1024),
#       %net.6.9.bn3.running_var : Float(1024),
#       %net.6.10.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.10.bn1.weight : Float(1024),
#       %net.6.10.bn1.bias : Float(1024),
#       %net.6.10.bn1.running_mean : Float(1024),
#       %net.6.10.bn1.running_var : Float(1024),
#       %net.6.10.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.10.bn2.weight : Float(1024),
#       %net.6.10.bn2.bias : Float(1024),
#       %net.6.10.bn2.running_mean : Float(1024),
#       %net.6.10.bn2.running_var : Float(1024),
#       %net.6.10.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.10.bn3.weight : Float(1024),
#       %net.6.10.bn3.bias : Float(1024),
#       %net.6.10.bn3.running_mean : Float(1024),
#       %net.6.10.bn3.running_var : Float(1024),
#       %net.6.11.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.11.bn1.weight : Float(1024),
#       %net.6.11.bn1.bias : Float(1024),
#       %net.6.11.bn1.running_mean : Float(1024),
#       %net.6.11.bn1.running_var : Float(1024),
#       %net.6.11.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.11.bn2.weight : Float(1024),
#       %net.6.11.bn2.bias : Float(1024),
#       %net.6.11.bn2.running_mean : Float(1024),
#       %net.6.11.bn2.running_var : Float(1024),
#       %net.6.11.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.11.bn3.weight : Float(1024),
#       %net.6.11.bn3.bias : Float(1024),
#       %net.6.11.bn3.running_mean : Float(1024),
#       %net.6.11.bn3.running_var : Float(1024),
#       %net.6.12.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.12.bn1.weight : Float(1024),
#       %net.6.12.bn1.bias : Float(1024),
#       %net.6.12.bn1.running_mean : Float(1024),
#       %net.6.12.bn1.running_var : Float(1024),
#       %net.6.12.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.12.bn2.weight : Float(1024),
#       %net.6.12.bn2.bias : Float(1024),
#       %net.6.12.bn2.running_mean : Float(1024),
#       %net.6.12.bn2.running_var : Float(1024),
#       %net.6.12.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.12.bn3.weight : Float(1024),
#       %net.6.12.bn3.bias : Float(1024),
#       %net.6.12.bn3.running_mean : Float(1024),
#       %net.6.12.bn3.running_var : Float(1024),
#       %net.6.13.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.13.bn1.weight : Float(1024),
#       %net.6.13.bn1.bias : Float(1024),
#       %net.6.13.bn1.running_mean : Float(1024),
#       %net.6.13.bn1.running_var : Float(1024),
#       %net.6.13.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.13.bn2.weight : Float(1024),
#       %net.6.13.bn2.bias : Float(1024),
#       %net.6.13.bn2.running_mean : Float(1024),
#       %net.6.13.bn2.running_var : Float(1024),
#       %net.6.13.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.13.bn3.weight : Float(1024),
#       %net.6.13.bn3.bias : Float(1024),
#       %net.6.13.bn3.running_mean : Float(1024),
#       %net.6.13.bn3.running_var : Float(1024),
#       %net.6.14.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.14.bn1.weight : Float(1024),
#       %net.6.14.bn1.bias : Float(1024),
#       %net.6.14.bn1.running_mean : Float(1024),
#       %net.6.14.bn1.running_var : Float(1024),
#       %net.6.14.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.14.bn2.weight : Float(1024),
#       %net.6.14.bn2.bias : Float(1024),
#       %net.6.14.bn2.running_mean : Float(1024),
#       %net.6.14.bn2.running_var : Float(1024),
#       %net.6.14.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.14.bn3.weight : Float(1024),
#       %net.6.14.bn3.bias : Float(1024),
#       %net.6.14.bn3.running_mean : Float(1024),
#       %net.6.14.bn3.running_var : Float(1024),
#       %net.6.15.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.15.bn1.weight : Float(1024),
#       %net.6.15.bn1.bias : Float(1024),
#       %net.6.15.bn1.running_mean : Float(1024),
#       %net.6.15.bn1.running_var : Float(1024),
#       %net.6.15.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.15.bn2.weight : Float(1024),
#       %net.6.15.bn2.bias : Float(1024),
#       %net.6.15.bn2.running_mean : Float(1024),
#       %net.6.15.bn2.running_var : Float(1024),
#       %net.6.15.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.15.bn3.weight : Float(1024),
#       %net.6.15.bn3.bias : Float(1024),
#       %net.6.15.bn3.running_mean : Float(1024),
#       %net.6.15.bn3.running_var : Float(1024),
#       %net.6.16.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.16.bn1.weight : Float(1024),
#       %net.6.16.bn1.bias : Float(1024),
#       %net.6.16.bn1.running_mean : Float(1024),
#       %net.6.16.bn1.running_var : Float(1024),
#       %net.6.16.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.16.bn2.weight : Float(1024),
#       %net.6.16.bn2.bias : Float(1024),
#       %net.6.16.bn2.running_mean : Float(1024),
#       %net.6.16.bn2.running_var : Float(1024),
#       %net.6.16.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.16.bn3.weight : Float(1024),
#       %net.6.16.bn3.bias : Float(1024),
#       %net.6.16.bn3.running_mean : Float(1024),
#       %net.6.16.bn3.running_var : Float(1024),
#       %net.6.17.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.17.bn1.weight : Float(1024),
#       %net.6.17.bn1.bias : Float(1024),
#       %net.6.17.bn1.running_mean : Float(1024),
#       %net.6.17.bn1.running_var : Float(1024),
#       %net.6.17.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.17.bn2.weight : Float(1024),
#       %net.6.17.bn2.bias : Float(1024),
#       %net.6.17.bn2.running_mean : Float(1024),
#       %net.6.17.bn2.running_var : Float(1024),
#       %net.6.17.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.17.bn3.weight : Float(1024),
#       %net.6.17.bn3.bias : Float(1024),
#       %net.6.17.bn3.running_mean : Float(1024),
#       %net.6.17.bn3.running_var : Float(1024),
#       %net.6.18.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.18.bn1.weight : Float(1024),
#       %net.6.18.bn1.bias : Float(1024),
#       %net.6.18.bn1.running_mean : Float(1024),
#       %net.6.18.bn1.running_var : Float(1024),
#       %net.6.18.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.18.bn2.weight : Float(1024),
#       %net.6.18.bn2.bias : Float(1024),
#       %net.6.18.bn2.running_mean : Float(1024),
#       %net.6.18.bn2.running_var : Float(1024),
#       %net.6.18.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.18.bn3.weight : Float(1024),
#       %net.6.18.bn3.bias : Float(1024),
#       %net.6.18.bn3.running_mean : Float(1024),
#       %net.6.18.bn3.running_var : Float(1024),
#       %net.6.19.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.19.bn1.weight : Float(1024),
#       %net.6.19.bn1.bias : Float(1024),
#       %net.6.19.bn1.running_mean : Float(1024),
#       %net.6.19.bn1.running_var : Float(1024),
#       %net.6.19.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.19.bn2.weight : Float(1024),
#       %net.6.19.bn2.bias : Float(1024),
#       %net.6.19.bn2.running_mean : Float(1024),
#       %net.6.19.bn2.running_var : Float(1024),
#       %net.6.19.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.19.bn3.weight : Float(1024),
#       %net.6.19.bn3.bias : Float(1024),
#       %net.6.19.bn3.running_mean : Float(1024),
#       %net.6.19.bn3.running_var : Float(1024),
#       %net.6.20.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.20.bn1.weight : Float(1024),
#       %net.6.20.bn1.bias : Float(1024),
#       %net.6.20.bn1.running_mean : Float(1024),
#       %net.6.20.bn1.running_var : Float(1024),
#       %net.6.20.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.20.bn2.weight : Float(1024),
#       %net.6.20.bn2.bias : Float(1024),
#       %net.6.20.bn2.running_mean : Float(1024),
#       %net.6.20.bn2.running_var : Float(1024),
#       %net.6.20.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.20.bn3.weight : Float(1024),
#       %net.6.20.bn3.bias : Float(1024),
#       %net.6.20.bn3.running_mean : Float(1024),
#       %net.6.20.bn3.running_var : Float(1024),
#       %net.6.21.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.21.bn1.weight : Float(1024),
#       %net.6.21.bn1.bias : Float(1024),
#       %net.6.21.bn1.running_mean : Float(1024),
#       %net.6.21.bn1.running_var : Float(1024),
#       %net.6.21.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.21.bn2.weight : Float(1024),
#       %net.6.21.bn2.bias : Float(1024),
#       %net.6.21.bn2.running_mean : Float(1024),
#       %net.6.21.bn2.running_var : Float(1024),
#       %net.6.21.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.21.bn3.weight : Float(1024),
#       %net.6.21.bn3.bias : Float(1024),
#       %net.6.21.bn3.running_mean : Float(1024),
#       %net.6.21.bn3.running_var : Float(1024),
#       %net.6.22.conv1.weight : Float(1024, 1024, 1, 1),
#       %net.6.22.bn1.weight : Float(1024),
#       %net.6.22.bn1.bias : Float(1024),
#       %net.6.22.bn1.running_mean : Float(1024),
#       %net.6.22.bn1.running_var : Float(1024),
#       %net.6.22.conv2.weight : Float(1024, 32, 3, 3),
#       %net.6.22.bn2.weight : Float(1024),
#       %net.6.22.bn2.bias : Float(1024),
#       %net.6.22.bn2.running_mean : Float(1024),
#       %net.6.22.bn2.running_var : Float(1024),
#       %net.6.22.conv3.weight : Float(1024, 1024, 1, 1),
#       %net.6.22.bn3.weight : Float(1024),
#       %net.6.22.bn3.bias : Float(1024),
#       %net.6.22.bn3.running_mean : Float(1024),
#       %net.6.22.bn3.running_var : Float(1024),
#       %net.7.0.conv1.weight : Float(2048, 1024, 1, 1),
#       %net.7.0.bn1.weight : Float(2048),
#       %net.7.0.bn1.bias : Float(2048),
#       %net.7.0.bn1.running_mean : Float(2048),
#       %net.7.0.bn1.running_var : Float(2048),
#       %net.7.0.conv2.weight : Float(2048, 64, 3, 3),
#       %net.7.0.bn2.weight : Float(2048),
#       %net.7.0.bn2.bias : Float(2048),
#       %net.7.0.bn2.running_mean : Float(2048),
#       %net.7.0.bn2.running_var : Float(2048),
#       %net.7.0.conv3.weight : Float(2048, 2048, 1, 1),
#       %net.7.0.bn3.weight : Float(2048),
#       %net.7.0.bn3.bias : Float(2048),
#       %net.7.0.bn3.running_mean : Float(2048),
#       %net.7.0.bn3.running_var : Float(2048),
#       %net.7.0.downsample.0.weight : Float(2048, 1024, 1, 1),
#       %net.7.0.downsample.1.weight : Float(2048),
#       %net.7.0.downsample.1.bias : Float(2048),
#       %net.7.0.downsample.1.running_mean : Float(2048),
#       %net.7.0.downsample.1.running_var : Float(2048),
#       %net.7.1.conv1.weight : Float(2048, 2048, 1, 1),
#       %net.7.1.bn1.weight : Float(2048),
#       %net.7.1.bn1.bias : Float(2048),
#       %net.7.1.bn1.running_mean : Float(2048),
#       %net.7.1.bn1.running_var : Float(2048),
#       %net.7.1.conv2.weight : Float(2048, 64, 3, 3),
#       %net.7.1.bn2.weight : Float(2048),
#       %net.7.1.bn2.bias : Float(2048),
#       %net.7.1.bn2.running_mean : Float(2048),
#       %net.7.1.bn2.running_var : Float(2048),
#       %net.7.1.conv3.weight : Float(2048, 2048, 1, 1),
#       %net.7.1.bn3.weight : Float(2048),
#       %net.7.1.bn3.bias : Float(2048),
#       %net.7.1.bn3.running_mean : Float(2048),
#       %net.7.1.bn3.running_var : Float(2048),
#       %net.7.2.conv1.weight : Float(2048, 2048, 1, 1),
#       %net.7.2.bn1.weight : Float(2048),
#       %net.7.2.bn1.bias : Float(2048),
#       %net.7.2.bn1.running_mean : Float(2048),
#       %net.7.2.bn1.running_var : Float(2048),
#       %net.7.2.conv2.weight : Float(2048, 64, 3, 3),
#       %net.7.2.bn2.weight : Float(2048),
#       %net.7.2.bn2.bias : Float(2048),
#       %net.7.2.bn2.running_mean : Float(2048),
#       %net.7.2.bn2.running_var : Float(2048),
#       %net.7.2.conv3.weight : Float(2048, 2048, 1, 1),
#       %net.7.2.bn3.weight : Float(2048),
#       %net.7.2.bn3.bias : Float(2048),
#       %net.7.2.bn3.running_mean : Float(2048),
#       %net.7.2.bn3.running_var : Float(2048),
#       %980 : Long(1)):
#   %625 : Float(1, 64, 150, 150) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 7], pads=[3, 3, 3, 3], strides=[2, 2]](%input_image, %net.0.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %626 : Float(1, 64, 150, 150) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%625, %net.1.weight, %net.1.bias, %net.1.running_mean, %net.1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %627 : Float(1, 64, 150, 150) = onnx::Relu(%626) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %628 : Float(1, 64, 75, 75) = onnx::MaxPool[ceil_mode=0, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%627) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:488:0
#   %629 : Float(1, 256, 75, 75) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%628, %net.4.0.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %630 : Float(1, 256, 75, 75) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%629, %net.4.0.bn1.weight, %net.4.0.bn1.bias, %net.4.0.bn1.running_mean, %net.4.0.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %631 : Float(1, 256, 75, 75) = onnx::Relu(%630) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %632 : Float(1, 256, 75, 75) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%631, %net.4.0.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %633 : Float(1, 256, 75, 75) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%632, %net.4.0.bn2.weight, %net.4.0.bn2.bias, %net.4.0.bn2.running_mean, %net.4.0.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %634 : Float(1, 256, 75, 75) = onnx::Relu(%633) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %635 : Float(1, 256, 75, 75) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%634, %net.4.0.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %636 : Float(1, 256, 75, 75) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%635, %net.4.0.bn3.weight, %net.4.0.bn3.bias, %net.4.0.bn3.running_mean, %net.4.0.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %637 : Float(1, 256, 75, 75) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%628, %net.4.0.downsample.0.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %638 : Float(1, 256, 75, 75) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%637, %net.4.0.downsample.1.weight, %net.4.0.downsample.1.bias, %net.4.0.downsample.1.running_mean, %net.4.0.downsample.1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %639 : Float(1, 256, 75, 75) = onnx::Add(%636, %638) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %640 : Float(1, 256, 75, 75) = onnx::Relu(%639) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %641 : Float(1, 256, 75, 75) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%640, %net.4.1.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %642 : Float(1, 256, 75, 75) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%641, %net.4.1.bn1.weight, %net.4.1.bn1.bias, %net.4.1.bn1.running_mean, %net.4.1.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %643 : Float(1, 256, 75, 75) = onnx::Relu(%642) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %644 : Float(1, 256, 75, 75) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%643, %net.4.1.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %645 : Float(1, 256, 75, 75) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%644, %net.4.1.bn2.weight, %net.4.1.bn2.bias, %net.4.1.bn2.running_mean, %net.4.1.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %646 : Float(1, 256, 75, 75) = onnx::Relu(%645) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %647 : Float(1, 256, 75, 75) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%646, %net.4.1.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %648 : Float(1, 256, 75, 75) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%647, %net.4.1.bn3.weight, %net.4.1.bn3.bias, %net.4.1.bn3.running_mean, %net.4.1.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %649 : Float(1, 256, 75, 75) = onnx::Add(%648, %640) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %650 : Float(1, 256, 75, 75) = onnx::Relu(%649) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %651 : Float(1, 256, 75, 75) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%650, %net.4.2.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %652 : Float(1, 256, 75, 75) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%651, %net.4.2.bn1.weight, %net.4.2.bn1.bias, %net.4.2.bn1.running_mean, %net.4.2.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %653 : Float(1, 256, 75, 75) = onnx::Relu(%652) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %654 : Float(1, 256, 75, 75) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%653, %net.4.2.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %655 : Float(1, 256, 75, 75) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%654, %net.4.2.bn2.weight, %net.4.2.bn2.bias, %net.4.2.bn2.running_mean, %net.4.2.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %656 : Float(1, 256, 75, 75) = onnx::Relu(%655) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %657 : Float(1, 256, 75, 75) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%656, %net.4.2.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %658 : Float(1, 256, 75, 75) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%657, %net.4.2.bn3.weight, %net.4.2.bn3.bias, %net.4.2.bn3.running_mean, %net.4.2.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %659 : Float(1, 256, 75, 75) = onnx::Add(%658, %650) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %660 : Float(1, 256, 75, 75) = onnx::Relu(%659) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %661 : Float(1, 512, 75, 75) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%660, %net.5.0.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %662 : Float(1, 512, 75, 75) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%661, %net.5.0.bn1.weight, %net.5.0.bn1.bias, %net.5.0.bn1.running_mean, %net.5.0.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %663 : Float(1, 512, 75, 75) = onnx::Relu(%662) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %664 : Float(1, 512, 38, 38) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%663, %net.5.0.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %665 : Float(1, 512, 38, 38) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%664, %net.5.0.bn2.weight, %net.5.0.bn2.bias, %net.5.0.bn2.running_mean, %net.5.0.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %666 : Float(1, 512, 38, 38) = onnx::Relu(%665) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %667 : Float(1, 512, 38, 38) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%666, %net.5.0.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %668 : Float(1, 512, 38, 38) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%667, %net.5.0.bn3.weight, %net.5.0.bn3.bias, %net.5.0.bn3.running_mean, %net.5.0.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %669 : Float(1, 512, 38, 38) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%660, %net.5.0.downsample.0.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %670 : Float(1, 512, 38, 38) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%669, %net.5.0.downsample.1.weight, %net.5.0.downsample.1.bias, %net.5.0.downsample.1.running_mean, %net.5.0.downsample.1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %671 : Float(1, 512, 38, 38) = onnx::Add(%668, %670) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %672 : Float(1, 512, 38, 38) = onnx::Relu(%671) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %673 : Float(1, 512, 38, 38) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%672, %net.5.1.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %674 : Float(1, 512, 38, 38) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%673, %net.5.1.bn1.weight, %net.5.1.bn1.bias, %net.5.1.bn1.running_mean, %net.5.1.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %675 : Float(1, 512, 38, 38) = onnx::Relu(%674) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %676 : Float(1, 512, 38, 38) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%675, %net.5.1.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %677 : Float(1, 512, 38, 38) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%676, %net.5.1.bn2.weight, %net.5.1.bn2.bias, %net.5.1.bn2.running_mean, %net.5.1.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %678 : Float(1, 512, 38, 38) = onnx::Relu(%677) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %679 : Float(1, 512, 38, 38) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%678, %net.5.1.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %680 : Float(1, 512, 38, 38) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%679, %net.5.1.bn3.weight, %net.5.1.bn3.bias, %net.5.1.bn3.running_mean, %net.5.1.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %681 : Float(1, 512, 38, 38) = onnx::Add(%680, %672) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %682 : Float(1, 512, 38, 38) = onnx::Relu(%681) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %683 : Float(1, 512, 38, 38) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%682, %net.5.2.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %684 : Float(1, 512, 38, 38) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%683, %net.5.2.bn1.weight, %net.5.2.bn1.bias, %net.5.2.bn1.running_mean, %net.5.2.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %685 : Float(1, 512, 38, 38) = onnx::Relu(%684) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %686 : Float(1, 512, 38, 38) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%685, %net.5.2.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %687 : Float(1, 512, 38, 38) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%686, %net.5.2.bn2.weight, %net.5.2.bn2.bias, %net.5.2.bn2.running_mean, %net.5.2.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %688 : Float(1, 512, 38, 38) = onnx::Relu(%687) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %689 : Float(1, 512, 38, 38) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%688, %net.5.2.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %690 : Float(1, 512, 38, 38) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%689, %net.5.2.bn3.weight, %net.5.2.bn3.bias, %net.5.2.bn3.running_mean, %net.5.2.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %691 : Float(1, 512, 38, 38) = onnx::Add(%690, %682) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %692 : Float(1, 512, 38, 38) = onnx::Relu(%691) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %693 : Float(1, 512, 38, 38) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%692, %net.5.3.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %694 : Float(1, 512, 38, 38) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%693, %net.5.3.bn1.weight, %net.5.3.bn1.bias, %net.5.3.bn1.running_mean, %net.5.3.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %695 : Float(1, 512, 38, 38) = onnx::Relu(%694) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %696 : Float(1, 512, 38, 38) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%695, %net.5.3.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %697 : Float(1, 512, 38, 38) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%696, %net.5.3.bn2.weight, %net.5.3.bn2.bias, %net.5.3.bn2.running_mean, %net.5.3.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %698 : Float(1, 512, 38, 38) = onnx::Relu(%697) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %699 : Float(1, 512, 38, 38) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%698, %net.5.3.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %700 : Float(1, 512, 38, 38) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%699, %net.5.3.bn3.weight, %net.5.3.bn3.bias, %net.5.3.bn3.running_mean, %net.5.3.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %701 : Float(1, 512, 38, 38) = onnx::Add(%700, %692) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %702 : Float(1, 512, 38, 38) = onnx::Relu(%701) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %703 : Float(1, 1024, 38, 38) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%702, %net.6.0.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %704 : Float(1, 1024, 38, 38) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%703, %net.6.0.bn1.weight, %net.6.0.bn1.bias, %net.6.0.bn1.running_mean, %net.6.0.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %705 : Float(1, 1024, 38, 38) = onnx::Relu(%704) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %706 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%705, %net.6.0.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %707 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%706, %net.6.0.bn2.weight, %net.6.0.bn2.bias, %net.6.0.bn2.running_mean, %net.6.0.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %708 : Float(1, 1024, 19, 19) = onnx::Relu(%707) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %709 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%708, %net.6.0.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %710 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%709, %net.6.0.bn3.weight, %net.6.0.bn3.bias, %net.6.0.bn3.running_mean, %net.6.0.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %711 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%702, %net.6.0.downsample.0.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %712 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%711, %net.6.0.downsample.1.weight, %net.6.0.downsample.1.bias, %net.6.0.downsample.1.running_mean, %net.6.0.downsample.1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %713 : Float(1, 1024, 19, 19) = onnx::Add(%710, %712) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %714 : Float(1, 1024, 19, 19) = onnx::Relu(%713) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %715 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%714, %net.6.1.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %716 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%715, %net.6.1.bn1.weight, %net.6.1.bn1.bias, %net.6.1.bn1.running_mean, %net.6.1.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %717 : Float(1, 1024, 19, 19) = onnx::Relu(%716) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %718 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%717, %net.6.1.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %719 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%718, %net.6.1.bn2.weight, %net.6.1.bn2.bias, %net.6.1.bn2.running_mean, %net.6.1.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %720 : Float(1, 1024, 19, 19) = onnx::Relu(%719) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %721 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%720, %net.6.1.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %722 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%721, %net.6.1.bn3.weight, %net.6.1.bn3.bias, %net.6.1.bn3.running_mean, %net.6.1.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %723 : Float(1, 1024, 19, 19) = onnx::Add(%722, %714) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %724 : Float(1, 1024, 19, 19) = onnx::Relu(%723) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %725 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%724, %net.6.2.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %726 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%725, %net.6.2.bn1.weight, %net.6.2.bn1.bias, %net.6.2.bn1.running_mean, %net.6.2.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %727 : Float(1, 1024, 19, 19) = onnx::Relu(%726) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %728 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%727, %net.6.2.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %729 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%728, %net.6.2.bn2.weight, %net.6.2.bn2.bias, %net.6.2.bn2.running_mean, %net.6.2.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %730 : Float(1, 1024, 19, 19) = onnx::Relu(%729) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %731 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%730, %net.6.2.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %732 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%731, %net.6.2.bn3.weight, %net.6.2.bn3.bias, %net.6.2.bn3.running_mean, %net.6.2.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %733 : Float(1, 1024, 19, 19) = onnx::Add(%732, %724) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %734 : Float(1, 1024, 19, 19) = onnx::Relu(%733) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %735 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%734, %net.6.3.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %736 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%735, %net.6.3.bn1.weight, %net.6.3.bn1.bias, %net.6.3.bn1.running_mean, %net.6.3.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %737 : Float(1, 1024, 19, 19) = onnx::Relu(%736) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %738 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%737, %net.6.3.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %739 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%738, %net.6.3.bn2.weight, %net.6.3.bn2.bias, %net.6.3.bn2.running_mean, %net.6.3.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %740 : Float(1, 1024, 19, 19) = onnx::Relu(%739) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %741 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%740, %net.6.3.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %742 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%741, %net.6.3.bn3.weight, %net.6.3.bn3.bias, %net.6.3.bn3.running_mean, %net.6.3.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
# ...
#   %892 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%891, %net.6.18.bn3.weight, %net.6.18.bn3.bias, %net.6.18.bn3.running_mean, %net.6.18.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %893 : Float(1, 1024, 19, 19) = onnx::Add(%892, %884) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %894 : Float(1, 1024, 19, 19) = onnx::Relu(%893) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %895 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%894, %net.6.19.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %896 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%895, %net.6.19.bn1.weight, %net.6.19.bn1.bias, %net.6.19.bn1.running_mean, %net.6.19.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %897 : Float(1, 1024, 19, 19) = onnx::Relu(%896) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %898 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%897, %net.6.19.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %899 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%898, %net.6.19.bn2.weight, %net.6.19.bn2.bias, %net.6.19.bn2.running_mean, %net.6.19.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %900 : Float(1, 1024, 19, 19) = onnx::Relu(%899) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %901 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%900, %net.6.19.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %902 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%901, %net.6.19.bn3.weight, %net.6.19.bn3.bias, %net.6.19.bn3.running_mean, %net.6.19.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %903 : Float(1, 1024, 19, 19) = onnx::Add(%902, %894) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %904 : Float(1, 1024, 19, 19) = onnx::Relu(%903) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %905 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%904, %net.6.20.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %906 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%905, %net.6.20.bn1.weight, %net.6.20.bn1.bias, %net.6.20.bn1.running_mean, %net.6.20.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %907 : Float(1, 1024, 19, 19) = onnx::Relu(%906) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %908 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%907, %net.6.20.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %909 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%908, %net.6.20.bn2.weight, %net.6.20.bn2.bias, %net.6.20.bn2.running_mean, %net.6.20.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %910 : Float(1, 1024, 19, 19) = onnx::Relu(%909) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %911 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%910, %net.6.20.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %912 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%911, %net.6.20.bn3.weight, %net.6.20.bn3.bias, %net.6.20.bn3.running_mean, %net.6.20.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %913 : Float(1, 1024, 19, 19) = onnx::Add(%912, %904) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %914 : Float(1, 1024, 19, 19) = onnx::Relu(%913) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %915 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%914, %net.6.21.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %916 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%915, %net.6.21.bn1.weight, %net.6.21.bn1.bias, %net.6.21.bn1.running_mean, %net.6.21.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %917 : Float(1, 1024, 19, 19) = onnx::Relu(%916) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %918 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%917, %net.6.21.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %919 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%918, %net.6.21.bn2.weight, %net.6.21.bn2.bias, %net.6.21.bn2.running_mean, %net.6.21.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %920 : Float(1, 1024, 19, 19) = onnx::Relu(%919) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %921 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%920, %net.6.21.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %922 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%921, %net.6.21.bn3.weight, %net.6.21.bn3.bias, %net.6.21.bn3.running_mean, %net.6.21.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %923 : Float(1, 1024, 19, 19) = onnx::Add(%922, %914) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %924 : Float(1, 1024, 19, 19) = onnx::Relu(%923) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %925 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%924, %net.6.22.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %926 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%925, %net.6.22.bn1.weight, %net.6.22.bn1.bias, %net.6.22.bn1.running_mean, %net.6.22.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %927 : Float(1, 1024, 19, 19) = onnx::Relu(%926) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %928 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%927, %net.6.22.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %929 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%928, %net.6.22.bn2.weight, %net.6.22.bn2.bias, %net.6.22.bn2.running_mean, %net.6.22.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %930 : Float(1, 1024, 19, 19) = onnx::Relu(%929) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %931 : Float(1, 1024, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%930, %net.6.22.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %932 : Float(1, 1024, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%931, %net.6.22.bn3.weight, %net.6.22.bn3.bias, %net.6.22.bn3.running_mean, %net.6.22.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %933 : Float(1, 1024, 19, 19) = onnx::Add(%932, %924) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %934 : Float(1, 1024, 19, 19) = onnx::Relu(%933) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %935 : Float(1, 2048, 19, 19) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%934, %net.7.0.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %936 : Float(1, 2048, 19, 19) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%935, %net.7.0.bn1.weight, %net.7.0.bn1.bias, %net.7.0.bn1.running_mean, %net.7.0.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %937 : Float(1, 2048, 19, 19) = onnx::Relu(%936) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %938 : Float(1, 2048, 10, 10) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%937, %net.7.0.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %939 : Float(1, 2048, 10, 10) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%938, %net.7.0.bn2.weight, %net.7.0.bn2.bias, %net.7.0.bn2.running_mean, %net.7.0.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %940 : Float(1, 2048, 10, 10) = onnx::Relu(%939) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %941 : Float(1, 2048, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%940, %net.7.0.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %942 : Float(1, 2048, 10, 10) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%941, %net.7.0.bn3.weight, %net.7.0.bn3.bias, %net.7.0.bn3.running_mean, %net.7.0.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %943 : Float(1, 2048, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%934, %net.7.0.downsample.0.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %944 : Float(1, 2048, 10, 10) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%943, %net.7.0.downsample.1.weight, %net.7.0.downsample.1.bias, %net.7.0.downsample.1.running_mean, %net.7.0.downsample.1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %945 : Float(1, 2048, 10, 10) = onnx::Add(%942, %944) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %946 : Float(1, 2048, 10, 10) = onnx::Relu(%945) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %947 : Float(1, 2048, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%946, %net.7.1.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %948 : Float(1, 2048, 10, 10) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%947, %net.7.1.bn1.weight, %net.7.1.bn1.bias, %net.7.1.bn1.running_mean, %net.7.1.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %949 : Float(1, 2048, 10, 10) = onnx::Relu(%948) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %950 : Float(1, 2048, 10, 10) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%949, %net.7.1.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %951 : Float(1, 2048, 10, 10) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%950, %net.7.1.bn2.weight, %net.7.1.bn2.bias, %net.7.1.bn2.running_mean, %net.7.1.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %952 : Float(1, 2048, 10, 10) = onnx::Relu(%951) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %953 : Float(1, 2048, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%952, %net.7.1.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %954 : Float(1, 2048, 10, 10) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%953, %net.7.1.bn3.weight, %net.7.1.bn3.bias, %net.7.1.bn3.running_mean, %net.7.1.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %955 : Float(1, 2048, 10, 10) = onnx::Add(%954, %946) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %956 : Float(1, 2048, 10, 10) = onnx::Relu(%955) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %957 : Float(1, 2048, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%956, %net.7.2.conv1.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %958 : Float(1, 2048, 10, 10) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%957, %net.7.2.bn1.weight, %net.7.2.bn1.bias, %net.7.2.bn1.running_mean, %net.7.2.bn1.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %959 : Float(1, 2048, 10, 10) = onnx::Relu(%958) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %960 : Float(1, 2048, 10, 10) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%959, %net.7.2.conv2.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %961 : Float(1, 2048, 10, 10) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%960, %net.7.2.bn2.weight, %net.7.2.bn2.bias, %net.7.2.bn2.running_mean, %net.7.2.bn2.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %962 : Float(1, 2048, 10, 10) = onnx::Relu(%961) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %963 : Float(1, 2048, 10, 10) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%962, %net.7.2.conv3.weight) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\modules\conv.py:342:0
#   %964 : Float(1, 2048, 10, 10) = onnx::BatchNormalization[epsilon=1e-05, momentum=0.9](%963, %net.7.2.bn3.weight, %net.7.2.bn3.bias, %net.7.2.bn3.running_mean, %net.7.2.bn3.running_var) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:1670:0
#   %965 : Float(1, 2048, 10, 10) = onnx::Add(%964, %956) # C:\ProgramData\Anaconda3\lib\site-packages\torchvision\models\resnet.py:114:0
#   %966 : Float(1, 2048, 10, 10) = onnx::Relu(%965) # C:\ProgramData\Anaconda3\lib\site-packages\torch\nn\functional.py:912:0
#   %967 : Float(1, 10, 10, 2048) = onnx::Transpose[perm=[0, 2, 3, 1]](%966) # <ipython-input-2-2cf955081d43>:11:0
#   %968 : Tensor = onnx::Shape(%967)
#   %969 : Tensor = onnx::Constant[value={0}]()
#   %970 : Long() = onnx::Gather[axis=0](%968, %969) # <ipython-input-2-2cf955081d43>:12:0
#   %971 : Tensor = onnx::Shape(%967)
#   %972 : Tensor = onnx::Constant[value={3}]()
#   %973 : Long() = onnx::Gather[axis=0](%971, %972) # <ipython-input-2-2cf955081d43>:12:0
#   %975 : Tensor = onnx::Unsqueeze[axes=[0]](%970)
#   %977 : Tensor = onnx::Unsqueeze[axes=[0]](%973)
#   %978 : Tensor = onnx::Concat[axis=0](%975, %980, %977)
#   %output_features : Float(1, 100, 2048) = onnx::Reshape(%967, %978) # <ipython-input-2-2cf955081d43>:12:0
#   return (%output_features)

# %%
# Load the resulting model for test
onnx_model = onnx.load("wsl_encoder.onnx")
onnx.checker.check_model(onnx_model)

ort_session = onnxruntime.InferenceSession("wsl_encoder.onnx")

def to_numpy(tensor):
    return tensor.detach().cpu().numpy() if tensor.requires_grad else tensor.cpu().numpy()

# Get output from onnx model
ort_inputs = {ort_session.get_inputs()[0].name: to_numpy(image)}
ort_outs = ort_session.run(None, ort_inputs)

# Compare the outputs between torch and onnx models
np.testing.assert_allclose(to_numpy(torch_features), ort_outs[0], rtol=1e-03, atol=1e-04)

print("Conversion successful!")

# %%
# Just in case, make sure the output tensor looks the same :)
torch.from_numpy(ort_outs[0])
# Out:
# tensor([[[0.0000, 0.2136, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0406, 0.0000, 0.0000],
#          ...,
#          [0.0000, 0.0000, 2.0856,  ..., 0.0000, 0.3631, 0.0000],
#          [0.0000, 0.0000, 1.6003,  ..., 0.0000, 0.9627, 0.0000],
#          [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]]])

# %%
# Now let's also check that the resulting model works correctly not only on the input that we used to get it
ort_inputs = {ort_session.get_inputs()[0].name: to_numpy(image_1)}
ort_outs = ort_session.run(None, ort_inputs)

np.testing.assert_allclose(to_numpy(torch_features_1), ort_outs[0], rtol=1e-03, atol=1e-04)

print("Conversion successful!")

# %% [markdown]
# ### Onnx-tf

# %% [markdown]
# Now we need to get *tensorflow* graph from our onnx model

# %%
from onnx_tf.backend import prepare

# %%
# Load model
model = onnx.load('wsl_encoder.onnx')

# Let's convert it to Tensorflow
tf_rep = prepare(model)

# Check inputs and outputs
print('inputs:', tf_rep.inputs)
print('outputs:', tf_rep.outputs)

# Print all internal operations
print('tensor_dict:', tf_rep.tensor_dict)

# %%
img_path = '0.jpg'
image = preprocessing_image(img_path)

# Let's run the same picture through the resulting graph
output = tf_rep.run(image)
# Let's see that we got the same tensor as in onnx
print("output:", output)
# Save the graph
tf_rep.export_graph('wsl_onnx_tf.pb')

# %% [markdown]
# ### Tf-protobuff

# %% [markdown]
# Now let's check the work of the resulting graph in *tensorflow*

# %%
# Reload the kernel to avoid errors - now we will work only with tensorflow
import tensorflow as tf

tf_encoder = "wsl_onnx_tf.pb"

# Specify the names of the input and output tensors
INPUT_TENSOR_NAME = 'input_image: 0'
OUTPUT_TENSOR_NAME = 'output_features: 0'

# Load the graph
with tf.io.gfile.GFile(tf_encoder,'rb') as encoder_pb:
    graph_enc = tf.compat.v1.GraphDef()
    graph_enc.ParseFromString(encoder_pb.read())
with tf.Graph().as_default() as encoder_graph:
    tf.import_graph_def(graph_enc, name="")

input_tensor = encoder_graph.get_tensor_by_name(INPUT_TENSOR_NAME)
output_tensor = encoder_graph.get_tensor_by_name(OUTPUT_TENSOR_NAME)

# Let's start a session that puts the result of passing through the graph of the input tensor into the specified output tensor
with tf.compat.v1.Session(graph=encoder_graph) as enc_sess:
    encoder_output = enc_sess.run(output_tensor, feed_dict={input_tensor: image.numpy()})  
encoder_output

# %%
# You can look at the graph itself
for op in encoder_graph.get_operations():
    print(op.values())
# Out:
# (<tf.Tensor 'Const:0' shape=(1,) dtype=int64>,)
# (<tf.Tensor 'Const_1:0' shape=(64, 3, 7, 7) dtype=float32>,)
# (<tf.Tensor 'Const_2:0' shape=(64,) dtype=float32>,)
# (<tf.Tensor 'Const_3:0' shape=(64,) dtype=float32>,)
# (<tf.Tensor 'Const_4:0' shape=(64,) dtype=float32>,)
# (<tf.Tensor 'Const_5:0' shape=(64,) dtype=float32>,)
# (<tf.Tensor 'Const_6:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_7:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_8:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_9:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_10:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_11:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_12:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_13:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_14:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_15:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_16:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_17:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_18:0' shape=(256, 64, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_19:0' shape=(256, 8, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_20:0' shape=(256, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_21:0' shape=(256, 64, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_22:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_23:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_24:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_25:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_26:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_27:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_28:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_29:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_30:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_31:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_32:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_33:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_34:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_35:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_36:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_37:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_38:0' shape=(256, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_39:0' shape=(256, 8, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_40:0' shape=(256, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_41:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_42:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_43:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_44:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_45:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_46:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_47:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_48:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_49:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_50:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_51:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_52:0' shape=(256,) dtype=float32>,)
# (<tf.Tensor 'Const_53:0' shape=(256, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_54:0' shape=(256, 8, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_55:0' shape=(256, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_56:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_57:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_58:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_59:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_60:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_61:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_62:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_63:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_64:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_65:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_66:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_67:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_68:0' shape=(512, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_69:0' shape=(512, 16, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_70:0' shape=(512, 512, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_71:0' shape=(512, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_72:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_73:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_74:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_75:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_76:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_77:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_78:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_79:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_80:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_81:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_82:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_83:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_84:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_85:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_86:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_87:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_88:0' shape=(512, 512, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_89:0' shape=(512, 16, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_90:0' shape=(512, 512, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_91:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_92:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_93:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_94:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_95:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_96:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_97:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_98:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_99:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_100:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_101:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_102:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_103:0' shape=(512, 512, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_104:0' shape=(512, 16, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_105:0' shape=(512, 512, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_106:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_107:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_108:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_109:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_110:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_111:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_112:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_113:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_114:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_115:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_116:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_117:0' shape=(512,) dtype=float32>,)
# (<tf.Tensor 'Const_118:0' shape=(512, 512, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_119:0' shape=(512, 16, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_120:0' shape=(512, 512, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_121:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_122:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_123:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_124:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_125:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_126:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_127:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_128:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_129:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_130:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_131:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_132:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_133:0' shape=(1024, 512, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_134:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_135:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_136:0' shape=(1024, 512, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_137:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_138:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_139:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_140:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_141:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_142:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_143:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_144:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_145:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_146:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_147:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_148:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_149:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_150:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_151:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_152:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_153:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_154:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_155:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_156:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_157:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_158:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_159:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_160:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_161:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_162:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_163:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_164:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_165:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_166:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_167:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_168:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_169:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_170:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_171:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_172:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_173:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_174:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_175:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_176:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_177:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_178:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_179:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_180:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_181:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_182:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_183:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_184:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_185:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_186:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_187:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_188:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_189:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_190:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_191:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_192:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_193:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_194:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_195:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_196:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_197:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_198:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_199:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_200:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_201:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_202:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_203:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_204:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_205:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_206:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_207:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_208:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_209:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_210:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_211:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_212:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_213:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_214:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_215:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_216:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_217:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_218:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_219:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_220:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_221:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_222:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_223:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_224:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_225:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_226:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_227:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_228:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_229:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_230:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_231:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_232:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_233:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_234:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_235:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_236:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_237:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_238:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_239:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_240:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_241:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_242:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_243:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_244:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_245:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_246:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_247:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_248:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_249:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_250:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_251:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_252:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_253:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_254:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_255:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_256:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_257:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_258:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_259:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_260:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_261:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_262:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_263:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_264:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_265:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_266:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_267:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_268:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_269:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_270:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_271:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_272:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_273:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_274:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_275:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_276:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_277:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_278:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_279:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_280:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_281:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_282:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_283:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_284:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_285:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_286:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_287:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_288:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_289:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_290:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_291:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_292:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_293:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_294:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_295:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_296:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_297:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_298:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_299:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_300:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_301:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_302:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_303:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_304:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_305:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_306:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_307:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_308:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_309:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_310:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_311:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_312:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_313:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_314:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_315:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_316:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_317:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_318:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_319:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_320:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_321:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_322:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_323:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_324:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_325:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_326:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_327:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_328:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_329:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_330:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_331:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_332:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_333:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_334:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_335:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_336:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_337:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_338:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_339:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_340:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_341:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_342:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_343:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_344:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_345:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_346:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_347:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_348:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_349:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_350:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_351:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_352:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_353:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_354:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_355:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_356:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_357:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_358:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_359:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_360:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_361:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_362:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_363:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_364:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_365:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_366:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_367:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_368:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_369:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_370:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_371:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_372:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_373:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_374:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_375:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_376:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_377:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_378:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_379:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_380:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_381:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_382:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_383:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_384:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_385:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_386:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_387:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_388:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_389:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_390:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_391:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_392:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_393:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_394:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_395:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_396:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_397:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_398:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_399:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_400:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_401:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_402:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_403:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_404:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_405:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_406:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_407:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_408:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_409:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_410:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_411:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_412:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_413:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_414:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_415:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_416:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_417:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_418:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_419:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_420:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_421:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_422:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_423:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_424:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_425:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_426:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_427:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_428:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_429:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_430:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_431:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_432:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_433:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_434:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_435:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_436:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_437:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_438:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_439:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_440:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_441:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_442:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_443:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_444:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_445:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_446:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_447:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_448:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_449:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_450:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_451:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_452:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_453:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_454:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_455:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_456:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_457:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_458:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_459:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_460:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_461:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_462:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_463:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_464:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_465:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_466:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_467:0' shape=(1024,) dtype=float32>,)
# (<tf.Tensor 'Const_468:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_469:0' shape=(1024, 32, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_470:0' shape=(1024, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_471:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_472:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_473:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_474:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_475:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_476:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_477:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_478:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_479:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_480:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_481:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_482:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_483:0' shape=(2048, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_484:0' shape=(2048, 64, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_485:0' shape=(2048, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_486:0' shape=(2048, 1024, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_487:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_488:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_489:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_490:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_491:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_492:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_493:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_494:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_495:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_496:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_497:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_498:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_499:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_500:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_501:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_502:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_503:0' shape=(2048, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_504:0' shape=(2048, 64, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_505:0' shape=(2048, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_506:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_507:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_508:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_509:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_510:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_511:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_512:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_513:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_514:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_515:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_516:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_517:0' shape=(2048,) dtype=float32>,)
# (<tf.Tensor 'Const_518:0' shape=(2048, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Const_519:0' shape=(2048, 64, 3, 3) dtype=float32>,)
# (<tf.Tensor 'Const_520:0' shape=(2048, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'input_image:0' shape=(None, 3, 299, 299) dtype=float32>,)
# (<tf.Tensor 'transpose/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose:0' shape=(7, 7, 3, 64) dtype=float32>,)
# (<tf.Tensor 'Const_521:0' shape=(4, 2) dtype=int32>,)
# (<tf.Tensor 'Pad:0' shape=(None, 3, 305, 305) dtype=float32>,)
# (<tf.Tensor 'Const_522:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split/split_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split:0' shape=(7, 7, 3, 64) dtype=float32>,)
# (<tf.Tensor 'transpose_1/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_1:0' shape=(None, 305, 305, 3) dtype=float32>,)
# (<tf.Tensor 'Const_523:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_1/split_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_1:0' shape=(None, 305, 305, 3) dtype=float32>,)
# (<tf.Tensor 'convolution:0' shape=(None, 150, 150, 64) dtype=float32>,)
# (<tf.Tensor 'concat/concat_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'concat:0' shape=(None, 150, 150, 64) dtype=float32>,)
# (<tf.Tensor 'transpose_2/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_2:0' shape=(None, 64, 150, 150) dtype=float32>,)
# (<tf.Tensor 'Reshape/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape:0' shape=(1, 64, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_1/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_1:0' shape=(1, 64, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_2/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_2:0' shape=(1, 64, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_3/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_3:0' shape=(1, 64, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm/add/y:0' shape=() dtype=float32>,)
# (<tf.Tensor 'batchnorm/add:0' shape=(1, 64, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm/Rsqrt:0' shape=(1, 64, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm/mul:0' shape=(1, 64, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm/mul_1:0' shape=(None, 64, 150, 150) dtype=float32>,)
# (<tf.Tensor 'batchnorm/mul_2:0' shape=(1, 64, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm/sub:0' shape=(1, 64, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm/add_1:0' shape=(None, 64, 150, 150) dtype=float32>,)
# (<tf.Tensor 'Relu:0' shape=(None, 64, 150, 150) dtype=float32>,)
# (<tf.Tensor 'transpose_3/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_3:0' shape=(None, 150, 150, 64) dtype=float32>,)
# (<tf.Tensor 'Shape:0' shape=(4,) dtype=int64>,)
# (<tf.Tensor 'strided_slice/stack:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice/stack_1:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice/stack_2:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice:0' shape=(2,) dtype=int64>,)
# (<tf.Tensor 'zeros:0' shape=(4,) dtype=int64>,)
# (<tf.Tensor 'add/y:0' shape=(4,) dtype=int64>,)
# (<tf.Tensor 'add:0' shape=(4,) dtype=int64>,)
# (<tf.Tensor 'strided_slice_1/stack:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_1/stack_1:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_1/stack_2:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_1:0' shape=() dtype=int64>,)
# (<tf.Tensor 'strided_slice_2/stack:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_2/stack_1:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_2/stack_2:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_2:0' shape=() dtype=int64>,)
# (<tf.Tensor 'strided_slice_3/stack:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_3/stack_1:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_3/stack_2:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_3:0' shape=() dtype=int64>,)
# (<tf.Tensor 'strided_slice_4/stack:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_4/stack_1:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_4/stack_2:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_4:0' shape=() dtype=int64>,)
# (<tf.Tensor 'PadV2/Cast:0' shape=() dtype=int32>,)
# (<tf.Tensor 'PadV2/Cast_1:0' shape=() dtype=int32>,)
# (<tf.Tensor 'PadV2/Cast_2:0' shape=() dtype=int32>,)
# (<tf.Tensor 'PadV2/Cast_3:0' shape=() dtype=int32>,)
# (<tf.Tensor 'PadV2/paddings/1:0' shape=(2,) dtype=int32>,)
# (<tf.Tensor 'PadV2/paddings/2:0' shape=(2,) dtype=int32>,)
# (<tf.Tensor 'PadV2/paddings/0_1:0' shape=(2,) dtype=int32>,)
# (<tf.Tensor 'PadV2/paddings/3_1:0' shape=(2,) dtype=int32>,)
# (<tf.Tensor 'PadV2/paddings:0' shape=(4, 2) dtype=int32>,)
# (<tf.Tensor 'PadV2/constant_values:0' shape=() dtype=float32>,)
# (<tf.Tensor 'PadV2:0' shape=(None, 152, 152, 64) dtype=float32>,)
# (<tf.Tensor 'Shape_1:0' shape=(4,) dtype=int64>,)
# (<tf.Tensor 'strided_slice_5/stack:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_5/stack_1:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_5/stack_2:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'strided_slice_5:0' shape=() dtype=int64>,)
# (<tf.Tensor 'zeros_1/mul/x:0' shape=() dtype=int64>,)
# (<tf.Tensor 'zeros_1/mul:0' shape=() dtype=int64>,)
# (<tf.Tensor 'zeros_1/Less/y:0' shape=() dtype=int64>,)
# (<tf.Tensor 'zeros_1/Less:0' shape=() dtype=bool>,)
# (<tf.Tensor 'zeros_1/Cast:0' shape=() dtype=int32>,)
# (<tf.Tensor 'zeros_1/packed/0:0' shape=() dtype=int32>,)
# (<tf.Tensor 'zeros_1/packed/1:0' shape=() dtype=int32>,)
# (<tf.Tensor 'zeros_1/packed:0' shape=(3,) dtype=int32>,)
# (<tf.Tensor 'zeros_1/Const:0' shape=() dtype=float32>,)
# (<tf.Tensor 'zeros_1:0' shape=(3, 3, None) dtype=float32>,)
# (<tf.Tensor 'Dilation2D:0' shape=(None, 75, 75, None) dtype=float32>,)
# (<tf.Tensor 'transpose_4/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_4:0' shape=(None, None, 75, 75) dtype=float32>,)
# (<tf.Tensor 'transpose_5/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_5:0' shape=(1, 1, 64, 256) dtype=float32>,)
# (<tf.Tensor 'Const_524:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_2/split_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_2:0' shape=(1, 1, 64, 256) dtype=float32>,)
# (<tf.Tensor 'transpose_6/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_6:0' shape=(None, 75, 75, None) dtype=float32>,)
# (<tf.Tensor 'Const_525:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_3/split_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_3:0' shape=(None, 75, 75, None) dtype=float32>,)
# (<tf.Tensor 'convolution_1:0' shape=(None, 75, 75, 256) dtype=float32>,)
# (<tf.Tensor 'concat_1/concat_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'concat_1:0' shape=(None, 75, 75, 256) dtype=float32>,)
# (<tf.Tensor 'transpose_7/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_7:0' shape=(None, 256, 75, 75) dtype=float32>,)
# (<tf.Tensor 'Reshape_4/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_4:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_5/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_5:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_6/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_6:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_7/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_7:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_1/add/y:0' shape=() dtype=float32>,)
# (<tf.Tensor 'batchnorm_1/add:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_1/Rsqrt:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_1/mul:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_1/mul_1:0' shape=(None, 256, 75, 75) dtype=float32>,)
# (<tf.Tensor 'batchnorm_1/mul_2:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_1/sub:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_1/add_1:0' shape=(None, 256, 75, 75) dtype=float32>,)
# (<tf.Tensor 'Relu_1:0' shape=(None, 256, 75, 75) dtype=float32>,)
# (<tf.Tensor 'transpose_8/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_8:0' shape=(3, 3, 8, 256) dtype=float32>,)
# (<tf.Tensor 'Const_526:0' shape=(4, 2) dtype=int32>,)
# (<tf.Tensor 'Pad_1:0' shape=(None, 256, 77, 77) dtype=float32>,)
# (<tf.Tensor 'Const_527:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_4/split_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_4:0' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:1' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:2' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:3' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:4' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:5' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:6' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:7' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:8' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:9' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:10' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:11' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:12' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:13' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:14' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:15' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:16' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:17' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:18' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:19' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:20' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:21' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:22' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:23' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:24' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:25' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:26' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:27' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:28' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:29' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:30' shape=(3, 3, 8, 8) dtype=float32>, <tf.Tensor 'split_4:31' shape=(3, 3, 8, 8) dtype=float32>)
# (<tf.Tensor 'transpose_9/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_9:0' shape=(None, 77, 77, 256) dtype=float32>,)
# (<tf.Tensor 'Const_528:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_5/split_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_5:0' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:1' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:2' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:3' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:4' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:5' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:6' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:7' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:8' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:9' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:10' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:11' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:12' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:13' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:14' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:15' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:16' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:17' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:18' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:19' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:20' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:21' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:22' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:23' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:24' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:25' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:26' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:27' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:28' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:29' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:30' shape=(None, 77, 77, 8) dtype=float32>, <tf.Tensor 'split_5:31' shape=(None, 77, 77, 8) dtype=float32>)
# (<tf.Tensor 'convolution_2:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_3:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_4:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_5:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_6:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_7:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_8:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_9:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_10:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_11:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_12:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_13:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_14:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_15:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_16:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_17:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_18:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_19:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_20:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_21:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_22:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_23:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_24:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_25:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_26:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_27:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_28:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_29:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_30:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_31:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_32:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'convolution_33:0' shape=(None, 75, 75, 8) dtype=float32>,)
# (<tf.Tensor 'concat_2/axis:0' shape=() dtype=int32>,)
# (<tf.Tensor 'concat_2:0' shape=(None, 75, 75, 256) dtype=float32>,)
# (<tf.Tensor 'transpose_10/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_10:0' shape=(None, 256, 75, 75) dtype=float32>,)
# (<tf.Tensor 'Reshape_8/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_8:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_9/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_9:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_10/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_10:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_11/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_11:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_2/add/y:0' shape=() dtype=float32>,)
# (<tf.Tensor 'batchnorm_2/add:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_2/Rsqrt:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_2/mul:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_2/mul_1:0' shape=(None, 256, 75, 75) dtype=float32>,)
# (<tf.Tensor 'batchnorm_2/mul_2:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_2/sub:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_2/add_1:0' shape=(None, 256, 75, 75) dtype=float32>,)
# (<tf.Tensor 'Relu_2:0' shape=(None, 256, 75, 75) dtype=float32>,)
# (<tf.Tensor 'transpose_11/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_11:0' shape=(1, 1, 256, 256) dtype=float32>,)
# (<tf.Tensor 'Const_529:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_6/split_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_6:0' shape=(1, 1, 256, 256) dtype=float32>,)
# (<tf.Tensor 'transpose_12/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_12:0' shape=(None, 75, 75, 256) dtype=float32>,)
# (<tf.Tensor 'Const_530:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_7/split_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_7:0' shape=(None, 75, 75, 256) dtype=float32>,)
# (<tf.Tensor 'convolution_34:0' shape=(None, 75, 75, 256) dtype=float32>,)
# (<tf.Tensor 'concat_3/concat_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'concat_3:0' shape=(None, 75, 75, 256) dtype=float32>,)
# (<tf.Tensor 'transpose_13/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_13:0' shape=(None, 256, 75, 75) dtype=float32>,)
# (<tf.Tensor 'Reshape_12/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_12:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_13/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_13:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_14/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_14:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_15/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_15:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_3/add/y:0' shape=() dtype=float32>,)
# (<tf.Tensor 'batchnorm_3/add:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_3/Rsqrt:0' shape=(1, 256, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_3/mul:0' shape=(1, 256, 1, 1) dtype=float32>,)
# ...
# (<tf.Tensor 'concat_100:0' shape=(None, 10, 10, 2048) dtype=float32>,)
# (<tf.Tensor 'transpose_304/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_304:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'Reshape_400/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_400:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_401/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_401:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_402/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_402:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_403/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_403:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_100/add/y:0' shape=() dtype=float32>,)
# (<tf.Tensor 'batchnorm_100/add:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_100/Rsqrt:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_100/mul:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_100/mul_1:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'batchnorm_100/mul_2:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_100/sub:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_100/add_1:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'Add_32:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'Relu_96:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'transpose_305/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_305:0' shape=(1, 1, 2048, 2048) dtype=float32>,)
# (<tf.Tensor 'Const_756:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_202/split_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_202:0' shape=(1, 1, 2048, 2048) dtype=float32>,)
# (<tf.Tensor 'transpose_306/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_306:0' shape=(None, 10, 10, 2048) dtype=float32>,)
# (<tf.Tensor 'Const_757:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_203/split_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_203:0' shape=(None, 10, 10, 2048) dtype=float32>,)
# (<tf.Tensor 'convolution_1093:0' shape=(None, 10, 10, 2048) dtype=float32>,)
# (<tf.Tensor 'concat_101/concat_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'concat_101:0' shape=(None, 10, 10, 2048) dtype=float32>,)
# (<tf.Tensor 'transpose_307/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_307:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'Reshape_404/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_404:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_405/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_405:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_406/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_406:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_407/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_407:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_101/add/y:0' shape=() dtype=float32>,)
# (<tf.Tensor 'batchnorm_101/add:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_101/Rsqrt:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_101/mul:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_101/mul_1:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'batchnorm_101/mul_2:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_101/sub:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_101/add_1:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'Relu_97:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'transpose_308/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_308:0' shape=(3, 3, 64, 2048) dtype=float32>,)
# (<tf.Tensor 'Const_758:0' shape=(4, 2) dtype=int32>,)
# (<tf.Tensor 'Pad_33:0' shape=(None, 2048, 12, 12) dtype=float32>,)
# (<tf.Tensor 'Const_759:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_204/split_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_204:0' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:1' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:2' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:3' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:4' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:5' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:6' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:7' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:8' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:9' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:10' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:11' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:12' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:13' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:14' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:15' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:16' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:17' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:18' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:19' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:20' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:21' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:22' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:23' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:24' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:25' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:26' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:27' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:28' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:29' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:30' shape=(3, 3, 64, 64) dtype=float32>, <tf.Tensor 'split_204:31' shape=(3, 3, 64, 64) dtype=float32>)
# (<tf.Tensor 'transpose_309/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_309:0' shape=(None, 12, 12, 2048) dtype=float32>,)
# (<tf.Tensor 'Const_760:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_205/split_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_205:0' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:1' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:2' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:3' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:4' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:5' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:6' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:7' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:8' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:9' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:10' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:11' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:12' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:13' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:14' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:15' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:16' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:17' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:18' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:19' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:20' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:21' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:22' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:23' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:24' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:25' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:26' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:27' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:28' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:29' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:30' shape=(None, 12, 12, 64) dtype=float32>, <tf.Tensor 'split_205:31' shape=(None, 12, 12, 64) dtype=float32>)
# (<tf.Tensor 'convolution_1094:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1095:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1096:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1097:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1098:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1099:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1100:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1101:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1102:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1103:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1104:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1105:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1106:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1107:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1108:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1109:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1110:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1111:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1112:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1113:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1114:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1115:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1116:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1117:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1118:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1119:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1120:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1121:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1122:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1123:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1124:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'convolution_1125:0' shape=(None, 10, 10, 64) dtype=float32>,)
# (<tf.Tensor 'concat_102/axis:0' shape=() dtype=int32>,)
# (<tf.Tensor 'concat_102:0' shape=(None, 10, 10, 2048) dtype=float32>,)
# (<tf.Tensor 'transpose_310/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_310:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'Reshape_408/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_408:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_409/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_409:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_410/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_410:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_411/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_411:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_102/add/y:0' shape=() dtype=float32>,)
# (<tf.Tensor 'batchnorm_102/add:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_102/Rsqrt:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_102/mul:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_102/mul_1:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'batchnorm_102/mul_2:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_102/sub:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_102/add_1:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'Relu_98:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'transpose_311/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_311:0' shape=(1, 1, 2048, 2048) dtype=float32>,)
# (<tf.Tensor 'Const_761:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_206/split_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_206:0' shape=(1, 1, 2048, 2048) dtype=float32>,)
# (<tf.Tensor 'transpose_312/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_312:0' shape=(None, 10, 10, 2048) dtype=float32>,)
# (<tf.Tensor 'Const_762:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_207/split_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'split_207:0' shape=(None, 10, 10, 2048) dtype=float32>,)
# (<tf.Tensor 'convolution_1126:0' shape=(None, 10, 10, 2048) dtype=float32>,)
# (<tf.Tensor 'concat_103/concat_dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'concat_103:0' shape=(None, 10, 10, 2048) dtype=float32>,)
# (<tf.Tensor 'transpose_313/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_313:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'Reshape_412/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_412:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_413/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_413:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_414/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_414:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'Reshape_415/shape:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'Reshape_415:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_103/add/y:0' shape=() dtype=float32>,)
# (<tf.Tensor 'batchnorm_103/add:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_103/Rsqrt:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_103/mul:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_103/mul_1:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'batchnorm_103/mul_2:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_103/sub:0' shape=(1, 2048, 1, 1) dtype=float32>,)
# (<tf.Tensor 'batchnorm_103/add_1:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'Add_33:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'Relu_99:0' shape=(None, 2048, 10, 10) dtype=float32>,)
# (<tf.Tensor 'transpose_314/perm:0' shape=(4,) dtype=int32>,)
# (<tf.Tensor 'transpose_314:0' shape=(None, 10, 10, 2048) dtype=float32>,)
# (<tf.Tensor 'Shape_2:0' shape=(4,) dtype=int64>,)
# (<tf.Tensor 'Const_763:0' shape=() dtype=int64>,)
# (<tf.Tensor 'GatherV2/axis:0' shape=() dtype=int32>,)
# (<tf.Tensor 'GatherV2:0' shape=() dtype=int64>,)
# (<tf.Tensor 'Shape_3:0' shape=(4,) dtype=int64>,)
# (<tf.Tensor 'Const_764:0' shape=() dtype=int64>,)
# (<tf.Tensor 'GatherV2_1/axis:0' shape=() dtype=int32>,)
# (<tf.Tensor 'GatherV2_1:0' shape=() dtype=int64>,)
# (<tf.Tensor 'ExpandDims/dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'ExpandDims:0' shape=(1,) dtype=int64>,)
# (<tf.Tensor 'ExpandDims_1/dim:0' shape=() dtype=int32>,)
# (<tf.Tensor 'ExpandDims_1:0' shape=(1,) dtype=int64>,)
# (<tf.Tensor 'concat_104/axis:0' shape=() dtype=int32>,)
# (<tf.Tensor 'concat_104:0' shape=(3,) dtype=int64>,)
# (<tf.Tensor 'Shape_4:0' shape=(4,) dtype=int64>,)
# (<tf.Tensor 'Const_765:0' shape=() dtype=int64>,)
# (<tf.Tensor 'Equal:0' shape=(3,) dtype=bool>,)
# (<tf.Tensor 'Where:0' shape=(None, 1) dtype=int64>,)
# (<tf.Tensor 'Squeeze:0' shape=(None,) dtype=int64>,)
# (<tf.Tensor 'GatherV2_2/axis:0' shape=() dtype=int32>,)
# (<tf.Tensor 'GatherV2_2:0' shape=(None,) dtype=int64>,)
# (<tf.Tensor 'Shape_5:0' shape=(1,) dtype=int32>,)
# (<tf.Tensor 'Cast:0' shape=(1,) dtype=int64>,)
# (<tf.Tensor 'SparseToDense/default_value:0' shape=() dtype=int64>,)
# (<tf.Tensor 'SparseToDense:0' shape=(3,) dtype=int64>,)
# (<tf.Tensor 'add_34:0' shape=(3,) dtype=int64>,)
# (<tf.Tensor 'output_features:0' shape=(None, None, None) dtype=float32>,)
# ()

# %% [markdown]
# ### Tensorflow Graph Transform

# %% [raw]
# Now, if we separately run the Tensorflow Graph Transform Tool with the command
# bazel-bin/tensorflow/tools/graph_transforms/summarize_graph --in_graph=wsl_onnx_tf.pb,
# we will see the following information:
#
# "Found 1 possible inputs: (name=input_image, type=float(1), shape=[?,3,299,299])
# No variables spotted.
# Found 3 possible outputs: (name=strided_slice, op=StridedSlice) (name=zeros_1/Less, op=Less) (name=output_features, op=Reshape)",
#
# which tells us that during the conversion, the output of the model (*"output_features"*) was not accurately recognized.
# Therefore, we will correct this drawback with the command below, at the same time optimizing the model using basic transformations.
#
# bazel-bin/tensorflow/tools/graph_transforms/transform_graph
# --in_graph=wsl_onnx_tf.pb
# --out_graph=optimized_wsl.pb
# --inputs='input_image'
# --outputs='output_features'
# --transforms='strip_unused_nodes(type=float, shape="?,3,299,299")
# remove_nodes(op=Identity, op=CheckNumerics)
# fold_constants(ignore_errors=true)
# fold_batch_norms
# fold_old_batch_norms'
#
# When restarted with an optimized model
# bazel-bin/tensorflow/tools/graph_transforms/summarize_graph --in_graph=optimized_wsl.pb
# we will see that the inputs and outputs are now displayed correctly.

# %% [markdown]
# ### Tf-saved_model

# %% [markdown]
# Now we will prepare the resulting model for serving by translating it into the appropriate special format *saved_model*

# %%
from tensorflow.python.saved_model import utils as smutils
from tensorflow.python.saved_model import signature_constants
from tensorflow.python.saved_model import signature_def_utils
from tensorflow.python.saved_model import tag_constants

# %%
optimized_encoder = "optimized_wsl.pb" 

# Repeat the above operations
with tf.io.gfile.GFile(optimized_encoder,'rb') as f:
    graph_def = tf.compat.v1.GraphDef()
    graph_def.ParseFromString(f.read())
with tf.Graph().as_default() as graph:
    tf.import_graph_def(graph_def, name="")

with tf.compat.v1.Session(graph=graph) as sess:
    export_dir = 'saved_encoder'

    input_tensor = graph.get_tensor_by_name('input_image: 0')  
    output_tensor = graph.get_tensor_by_name('output_features: 0')

    # Set the names of inputs and outputs for serving
    tensor_info_inputs = {'images': smutils.build_tensor_info(input_tensor)}

    tensor_info_outputs = {'extracted_features': smutils.build_tensor_info(output_tensor)} 

    prediction_signature = signature_def_utils.build_signature_def(
                            inputs=tensor_info_inputs,
                            outputs=tensor_info_outputs,
                            method_name=signature_constants.PREDICT_METHOD_NAME)

    builder = tf.compat.v1.saved_model.builder.SavedModelBuilder(export_dir)
    builder.add_meta_graph_and_variables(
        sess, [tag_constants.SERVING],
        signature_def_map={signature_constants.DEFAULT_SERVING_SIGNATURE_DEF_KEY: prediction_signature})
    builder.save()
# Out:
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: saved_encoder\saved_model.pb

# %% [markdown]
# ### Tf-serving

# %% [raw]
# The above folder with the model (./saved_encoder/saved_model.pb) put in a folder called "1" (model version) in the right place for us (/home/Projects/encoder).
# To run on the CPU, use the command
# "tensorflow_model_server --enable_batching --port=9000 --model_name=saved_model.pb --model_base_path=/home/Projects/encoder".
#
# To run the GPU version of Tensorflow Model Server, you first need to install the docker version of the serving, and then run it with the command like
# "sudo docker run --rm --runtime=nvidia --name serving_encoder -p 9000:8500 --mount type=bind,source=/home/Projects,target=/models -e MODEL_NAME=encoder -t tensorflow/serving:2.3.0-gpu"

# %% [markdown]
# Now let's see how to start serving our model on the server.

# %%
import grpc
import numpy as np
from tensorflow_serving.apis import predict_pb2
from tensorflow_serving.apis import prediction_service_pb2_grpc
from PIL import Image

# %%
# Increase the message lengths of the request and create a channel for it
options = [('grpc.max_send_message_length', 512 * 1024 * 1024), ('grpc.max_receive_message_length', 512 * 1024 * 1024)]
channel = grpc.insecure_channel('0.0.0.0:9000', options = options)
stub = prediction_service_pb2_grpc.PredictionServiceStub(channel)

# Specify the same model name that we specified in the commands above
request_encoder = predict_pb2.PredictRequest()
request_encoder.model_spec.name = 'encoder'

# %%
image = 'here is our preprocessed image converted to numpy array'

# Send an image to the model, at the output we get a numpy array of features
request_encoder.inputs['images'].CopyFrom(tf.make_tensor_proto(image))
encoder_out = tf.make_ndarray(stub.Predict(request_encoder).outputs['extracted_features'])

# %% [markdown]
# Done - the model is spinning :)
